# %%
from cgan import ConditionalGAN
from matplotlib import pyplot

# %%
cgan = ConditionalGAN()

# %%
generated_samples = cgan.RunGan()
# Out:
# Epoch: 0 | Final Batch Size: 13 | Loss D: 0.6851 | Loss G: 0.6976

# %%
pyplot.plot(generated_samples[:, 0], generated_samples[:, 1], ".")
